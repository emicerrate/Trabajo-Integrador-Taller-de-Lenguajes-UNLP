# %%
import sys
sys.path.append("..")

# %%
from src.constantes import DATA_OUT_PATH, DATA_PATH
from src.funcionesI import all_togetherI, university

archivo_completo = DATA_PATH / "usu_individual_total.csv"
archivo_salida = DATA_OUT_PATH / "usu_individual_final.csv"

all_togetherI(archivo_completo)
university(archivo_completo, archivo_salida)
