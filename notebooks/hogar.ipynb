# %%
import sys
sys.path.append("..")

# %%
from src.constantes import DATA_OUT_PATH, DATA_PATH
from src.funcionesH import all_togetherH, home_density

archivo_completo = DATA_PATH / "usu_hogar_total.csv"
archivo_salida = DATA_OUT_PATH / "usu_hogar_final.csv"

all_togetherH(archivo_completo)
home_density(archivo_completo, archivo_salida)
