# %%
import sys
sys.path.append("..")

# %%
from src.constantes import DATA_OUT_PATH, DATA_PATH
from src.funcionesH import all_togetherH, home_type, home_density, set_habitability_condition, material

archivo_inicial = DATA_PATH / "usu_hogar_inicial.csv"
archivo_parcial = DATA_PATH / "usu_hogar_parcial.csv"
archivo_salida = DATA_OUT_PATH / "usu_hogar_final.csv"

all_togetherH(archivo_inicial)
home_type(archivo_inicial)
material(archivo_inicial, archivo_parcial)
home_density(archivo_inicial, archivo_parcial)
set_habitability_condition(archivo_parcial, archivo_salida)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 9
#       6 archivo_salida = DATA_OUT_PATH / "usu_hogar_final.csv"
#       8 all_togetherH(archivo_inicial)
# ----> 9 home_type(archivo_inicial)
#      10 material(archivo_inicial, archivo_parcial)
#      11 home_density(archivo_inicial, archivo_parcial)
#
# File d:\00_Facultad\Ciencia de Datos en Organizaciones\Taller de Lenguajes\Practica 3 - Trabajo Integrador\code\notebooks\..\src\funcionesH.py:37, in home_type(data)
#      35     reader = csv.DictReader(file_in, delimiter=";")
#      36     rows = list(reader)
# ---> 37     columns = reader.fieldnames + ["TIPO_HOGAR"]
#      39 # Escribir los datos con la nueva columna
#      40 with data.open("w", newline="") as file_out:
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'list'
