# %%
import sys
sys.path.append("..")

# %%
from src.constantes import DATA_OUT_PATH

archivo_individual = DATA_OUT_PATH / "usu_individual_final.csv"
archivo_hogar = DATA_OUT_PATH / "usu_hogar_final.csv"

# %%
#Inciso 1:
from src.funcionesT import literacy
literacy(archivo_individual)

# %%
#Inciso 2:
from src.funcionesT import foreign_university_student_percent
foreign_university_student_percent(archivo_individual)

# %%
#Inciso 5:
from src.funcionesT import owners_occupation_per_ag
owners_occupation_per_ag(archivo_hogar)

# %%
#Inciso 6:
from src.funcionesT import max_homes_cluster
max_homes_cluster(archivo_hogar)

# %%
#Inciso 7:
from src.funcionesT import percentage_university_level_clusters
percentage_university_level_clusters(archivo_individual)

# %%
#Inciso 8:
from src.funcionesT import tenant_for_region
tenant_for_region(archivo_hogar)

# %%
#Inciso 9:
from src.funcionesT import adults_per_education_level
adults_per_education_level(archivo_individual)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 #Inciso 9:
# ----> 2 from src.funcionesT import adults_per_education_level
#       3 adults_per_education_level(archivo_individual)
#
# ModuleNotFoundError: No module named 'src'

# %%
#Inciso 10:
from src.funcionesT import compare_unfinished_high_school
compare_unfinished_high_school(archivo_individual)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 #Inciso 10:
# ----> 2 from src.funcionesT import compare_unfinished_high_school
#       3 compare_unfinished_high_school(archivo_individual)
#
# ModuleNotFoundError: No module named 'src'

# %%
#Inciso 12:
from src.funcionesT import retired_insufficient
retired_insufficient(archivo_individual, archivo_hogar)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 #Inciso 12:
# ----> 2 from src.funcionesT import retired_insufficient
#       3 retired_insufficient(archivo_individual, archivo_hogar)
#
# ModuleNotFoundError: No module named 'src'

# %%
#Inciso 13:
from src.funcionesT import university_insufficient
university_insufficient(archivo_individual, archivo_hogar)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 #Inciso 13:
# ----> 2 from src.funcionesT import university_insufficient
#       3 university_insufficient(archivo_individual, archivo_hogar)
#
# ModuleNotFoundError: No module named 'src'
