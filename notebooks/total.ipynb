# %% [markdown]
# # **Sección B**: consultas al dataset principal

# %% [markdown]
# ### **Configuración del path, las rutas de acceso a los archivos e importación de las funciones correspondientes a cada ejercicio**

# %%
import sys
sys.path.append("..")

from src.constantes import DATA_OUT_PATH
from src.funcionesT import literacy, foreign_university_student_percent, owners_occupation_per_ag, max_homes_cluster, percentage_university_level_clusters
from src.funcionesT import tenant_for_region, adults_per_education_level, compare_unfinished_high_school, retired_insufficient, top5_university_occupancy
from src.funcionesT import university_insufficient, unemployment, percentage_precarious_material

archivo_individual = DATA_OUT_PATH / "usu_individual_final.csv"
archivo_hogar = DATA_OUT_PATH / "usu_hogar_final.csv"

# %% [markdown]
# ## **Tomando como fuente los datasets generados en la sección A y sus nuevas columnas:**

# %% [markdown]
# ### **1. A partir de la información de cada año contenida en el dataset se informa, año tras año, el porcentaje de personas mayores a 2 años capaces e incapaces de leer y escribir.**
#
# **La información es procesada sobre el último trimestre de cada año.**

# %%
literacy(archivo_individual)
# Out:
# 'El archivo de entrada está vacío.'

# %% [markdown]
# ### **2. A partir de un año y trimestre elegido por el usuario se informa el porcentaje de personas no nacidas en Argentina que hayan cursado un nivel universitario o superior.**

# %%
foreign_university_student_percent(archivo_individual)
# Out:
# No hay información sobre el trimestre seleccionado

# %% [markdown]
# ### **3. A partir de la información contenida en el dataset se informa el año y trimestre donde hubo menor desocupación.**

# %%
unemployment(archivo_individual)
# Out:
# 'El archivo de entrada está vacío.'

# %% [markdown]
# ### **4. Ranking de los 5 aglomerados con mayor porcentaje de hogares con dos o más ocupantes con estudios universitarios o superiores finalizados. Información obtenida a partir del par de archivos más recientes.**

# %%
top5_university_occupancy(archivo_individual, archivo_hogar)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 top5_university_occupancy(archivo_individual, archivo_hogar)
#
# File d:\00_Facultad\Ciencia de Datos en Organizaciones\Taller de Lenguajes\Practica 3 - Trabajo Integrador\code\notebooks\..\src\funcionesT.py:527, in top5_university_occupancy(path_individual, path_home)
#     524 ag_id = agglomeration_id()
#     526 # Calculo el ultimo trimestre y me guardo su número y el año correspondiente
# --> 527 max_year, max_quarter = last_quarter(path_individual)
#     530 with path_individual.open("r", newline="") as individual, path_home.open("r", newline="") as home:
#     531     individual_reader = csv.DictReader(individual, delimiter=";")
#
# ...

# %% [markdown]
# ### **5. Se informa para cada aglomerado el porcentaje de viviendas ocupadas por sus propietarios**

# %%
owners_occupation_per_ag(archivo_hogar)

# %% [markdown]
# ### **6. Se informa el aglomerado con mayor cantidad de viviendas con más de dos ocupantes y sin baño. Se informa también la cantidad de ellas.**

# %%
max_homes_cluster(archivo_hogar)

# %% [markdown]
# ### **7. Se informa para cada aglomerado el porcentaje de personas que hayan cursado al menos en nivel universitario o superior.**

# %%
percentage_university_level_clusters(archivo_individual)

# %% [markdown]
# ### **8. Se ordena las regiones de forma descendente según el porcentaje de inquilinos de cada una.**

# %%
tenant_for_region(archivo_hogar)

# %% [markdown]
# ### **9. Se pide al usuario que seleccione un aglomerado y a partir de la información contenida se retorna una tabla que contiene la cantidad de personas mayores de edad según su nivel de estudios alcanzados.**

# %%
adults_per_education_level(archivo_individual)

# %% [markdown]
# ### **10. Se pide al usuario que seleccione dos aglomerados y a partir de la información contenida se retorna una tabla que conteniene el porcentaje de personas mayores de edad con secundario incompleto.**

# %%
compare_unfinished_high_school(archivo_individual)

# %% [markdown]
# ### **11. Se pide al usuario que seleccione un año, se busca e imprime el último trimestre almacenado del mencionado año, el aglomerado con mayor porcentaje de viviendas de “Material precario” y el aglomerado con menor porcentaje de viviendas de “Material precario”.**

# %%
percentage_precarious_material(archivo_hogar)

# %% [markdown]
# ### **12. A partir de la información del último trimestre almacenado en el sistema se retorna para cada aglomerado el porcentaje de jubilados que viven en una vivienda con CONDICION_DE_HABITABILIDAD insuficiente**

# %%
retired_insufficient(archivo_individual, archivo_hogar)

# %% [markdown]
# ### **13. Se solicita un año al usuario y a partir de la información del último trimestre de dicho ejercicio se informa la cantidad de personas que hayan cursado nivel universitario o superior y que vivan en una vivienda con CONDICION_DE_HABITABILIDAD insuficiente**

# %%
university_insufficient(archivo_individual, archivo_hogar)
