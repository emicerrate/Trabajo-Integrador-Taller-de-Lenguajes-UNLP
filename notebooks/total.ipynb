# %%
import sys
sys.path.append("..")

# %%
from src.constantes import DATA_OUT_PATH
from src.funcionesT import compare_unfinished_high_school, retired_insufficient, foreign_university_student_percent

archivo_individual = DATA_OUT_PATH / "usu_individual_final.csv"
archivo_hogar = DATA_OUT_PATH / "usu_hogar_final.csv"

#Inciso 2:
foreign_university_student_percent(archivo_individual)
compare_unfinished_high_school(archivo_individual)
retired_insufficient(archivo_individual, archivo_hogar)
# Out:
# AÑO: 2024 TRIMESTRE: 3
# Porcentaje de personas no nacidas en Argentina que cursaron un nivel universitario o superior: 32.609%
# Año    Trimestre   Aglomerado 12        Aglomerado 13
# 2016   2           14.97%               19.27%
# 2018   4           15.15%               16.06%
# 2020   1           15.37%               16.95%
# 2020   2           16.88%               18.07%
# 2021   3           0.00%                0.00%
# 2022   2           17.55%               16.64%
# 2022   4           14.76%               18.56%
# 2023   3           15.96%               17.61%
# 2023   4           15.99%               17.89%
# 2024   1           14.30%               17.55%
# 2024   2           14.41%               18.48%
# 2024   3           14.11%               16.78%
# 2024   4           0.00%                0.00%
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 10
#       8 foreign_university_student_percent(archivo_individual)
#       9 compare_unfinished_high_school(archivo_individual)
# ---> 10 retired_insufficient(archivo_individual, archivo_hogar)
#
# File c:\Users\Urri\Desktop\ej python\Taller de lenguajes\repo trabajo integrador\notebooks\..\src\funcionesT.py:105, in retired_insufficient(path_individual, path_home)
#     103 for person in individual_reader:
#     104     if person["ANO4"] == str(max_year) and person["TRIMESTRE"] == str(max_quarter):
# --> 105         if person["CONDICION_LABORAL"] == "Inactivo" and person["CAT_INAC"] == "1":
#     106             retired_counter.update({person["AGLOMERADO"]: 1})
#     107             if houses[person["CODUSU"]]["CONDICION_DE_HABITABILIDAD"] == "INSUFICIENTE":
#
# KeyError: 'CONDICION_LABORAL'
